# %%
# invest 라이브러리 로드 
import invest

# %%
import importlib
importlib.reload(invest)
# Out:
# <module 'invest' from 'c:\\ubion_2025\\python\\250326\\invest\\__init__.py'>

# %%
import pandas as pd

# %%
# invest 라이브러리 
# load_data()
# Invest Class
    # 투자 전략 3개를 사용할 수 있는 class

df = pd.read_csv("../../csv/AAPL.csv")

# %%
df2 = invest.load_data('AAPL')

# %%
df.head()

# %%
df2.head()

# %%
# Invest Class를 생성
class1 = invest.Invest(df)

# %%
class2 = invest.Invest(df2, _col = 'Close')

# %%
print(class1.start, class1.end, class1.col)
# Out:
# 2010-01-01 00:00:00 2025-03-26 17:12:00.216214 Adj Close

# %%
class1.df
# Out:
#              Adj Close
# Date
# 1980-12-12    0.410525
# 1980-12-15    0.389106
# 1980-12-16    0.360548
# 1980-12-17    0.369472
# 1980-12-18    0.380182
# ...                ...
# 2019-06-18  198.449997
# 2019-06-19  197.869995
# 2019-06-20  199.460007
# 2019-06-21  198.779999
# 2019-06-24  199.169998
#
# [9713 rows x 1 columns]

# %%
class1.buyandhold()
# Out:
# 2010-01-01 00:00:00
# 2025-03-26 17:20:38.977905
# Adj Close
# 바이앤홀드 df :  2384
# 2010-01-01부터
#           2025-03-26까지
#           buyandhold의 수익율은 7.436513727083075입니다
# 투자기간 : 2010-01-01 00:00:00 ~ 2025-03-26 17:20:38.977905, 총 수익율 : 7.436513727083075
#              Adj Close  daily_rtn   acc_rtn
# Date
# 2010-01-04   26.782711   1.000000  1.000000
# 2010-01-05   26.829010   1.001729  1.001729
# 2010-01-06   26.402260   0.984094  0.985795
# 2010-01-07   26.353460   0.998152  0.983973
# 2010-01-08   26.528664   1.006648  0.990515
# ...                ...        ...       ...
# 2019-06-18  198.449997   1.023518  7.409631
# 2019-06-19  197.869995   0.997077  7.387975
# 2019-06-20  199.460007   1.008036  7.447342
# 2019-06-21  198.779999   0.996591  7.421952
# 2019-06-24  199.169998   1.001962  7.436514
#
# [2384 rows x 3 columns]

# %%
class1.bollinger()
# Out:
# 매수일 : 2010-01-22 00:00:00, 매수가 : 24.747818
# 매도일 : 2010-03-01 00:00:00, 매도가 : 26.154476
# 수익율 : 1.0568396777445188
# 매수일 : 2010-08-24 00:00:00, 매수가 : 30.026524
# 매도일 : 2010-09-08 00:00:00, 매도가 : 32.90366
# 수익율 : 1.0958198158401553
# 매수일 : 2011-03-16 00:00:00, 매수가 : 41.299767
# 매도일 : 2011-07-01 00:00:00, 매도가 : 42.957966
# 수익율 : 1.040150323366231
# 매수일 : 2011-11-14 00:00:00, 매수가 : 47.463268
# 매도일 : 2011-12-27 00:00:00, 매도가 : 50.876015
# 수익율 : 1.0719029081604747
# 매수일 : 2012-04-16 00:00:00, 매수가 : 72.601524
# 매도일 : 2012-06-18 00:00:00, 매도가 : 73.308609
# 수익율 : 1.0097392583659814
# c:\ubion_2025\python\250326\invest\__init__.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.0568396777445188' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   result.loc[idx, 'rtn'] = rtn
# 매수일 : 2012-10-08 00:00:00, 매수가 : 80.207954
# 매도일 : 2013-07-29 00:00:00, 매도가 : 57.243137
# ...

# %%
class1.momentum()
# Out:
# c:\ubion_2025\python\250326\invest\quant\momentum.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF1'] = result.shift(1)[col]
# c:\ubion_2025\python\250326\invest\quant\momentum.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF2'] = result.shift(_momentum)[col]
# 날짜 : 2010-01-29 00:00:00, 모멘텀 인덱스 : 1.338067378873177, signal : buy
# 날짜 : 2010-02-26 00:00:00, 모멘텀 인덱스 : 1.1504870903585878, signal : buy
# ...
